# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
digits = load_digits()

# %%
plt.gray()
plt.matshow(digits.images[0])
plt.title(f"Label: {digits.target[0]}")
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    digits.data, digits.target, test_size=0.2, random_state=42)

# %%
model = LogisticRegression(max_iter=10000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
accuracy = model.score(X_test, y_test)
print(f"🎯 Précision du modèle : {accuracy:.2f}")
# Out:
# 🎯 Précision du modèle : 0.97

# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

# %%
digits = load_digits()

# %%
index = 66  # غيّرو لأي رقم آخر
image = digits.images[index]
data = digits.data[index].reshape(1, -1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    digits.data, digits.target, test_size=0.2, random_state=42)

# %%
model = LogisticRegression(max_iter=10000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
predicted = model.predict(data)[0]
real = digits.target[index]

# %%
plt.gray()
plt.matshow(image)
plt.title(f"✅ Réel: {real} | 🤖 Prédit: {predicted}")
plt.show()
# Out:
# C:\Users\youness\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9989 (\N{WHITE HEAVY CHECK MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\youness\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129302 (\N{ROBOT FACE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
